# %%
import numpy as np
import pandas as pd
filepath = "datasets/athletes/"
data_main = pd.read_csv(filepath + "Medals.csv", encoding= "ISO-8859-1") # normalmente es utf-8

# %%
data_main
# Out:
#                    Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0           Michael Phelps  23.0  2008            08/24/2008            8
# 1           Michael Phelps  19.0  2004            08/29/2004            6
# 2           Michael Phelps  27.0  2012            08/12/2012            4
# 3         Natalie Coughlin  25.0  2008            08/24/2008            1
# 4            Aleksey Nemov  24.0  2000            10/01/2000            2
# ...                    ...   ...   ...                   ...          ...
# 8613      Olena Sadovnycha  32.0  2000            10/01/2000            0
# 8614      Kateryna Serdiuk  17.0  2000            10/01/2000            0
# 8615      Wietse van Alten  21.0  2000            10/01/2000            0
# 8616  Sandra Wagner-Sachse  31.0  2000            10/01/2000            0
# 8617             Rod White  23.0  2000            10/01/2000            0
#
#       Silver Medals  Bronze Medals  Total Medals
# ...

# %%
medallas=data_main.head(10)

# %%
data_main.head(15)
# Out:
#              Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008            08/24/2008            8
# 1     Michael Phelps  19.0  2004            08/29/2004            6
# 2             Daniel  27.0  2012            08/12/2012            4
# 3   Natalie Coughlin  25.0  2008            08/24/2008            1
# 4      Aleksey Nemov  24.0  2000            10/01/2000            2
# 5      Alicia Coutts  24.0  2012            08/12/2012            1
# 6     Missy Franklin  17.0  2012            08/12/2012            4
# 7        Ryan Lochte  27.0  2012            08/12/2012            2
# 8    Allison Schmitt  22.0  2012            08/12/2012            3
# 9   Natalie Coughlin  21.0  2004            08/29/2004            2
# 10        Ian Thorpe  17.0  2000            10/01/2000            3
# 11       Dara Torres  33.0  2000            10/01/2000            2
# 12     Cindy Klassen  26.0  2006            02/26/2006            1
# ...

# %%
medallas_cp =data_main[0:10].copy()

# %%
medallas_cp
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2            Daniel  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
# 5     Alicia Coutts  24.0  2012            08/12/2012            1
# 6    Missy Franklin  17.0  2012            08/12/2012            4
# 7       Ryan Lochte  27.0  2012            08/12/2012            2
# 8   Allison Schmitt  22.0  2012            08/12/2012            3
# 9  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# ...

# %%
medallas_cp.loc[2,'Athlete']
# Out:
# 'Daniel'

# %%
data_country = pd.read_csv(filepath + "Athelete_Country_Map.csv", encoding = "ISO-8859-1")

# %%
data_country
# Out:
#                    Athlete        Country
# 0           Michael Phelps  United States
# 1         Natalie Coughlin  United States
# 2            Aleksey Nemov         Russia
# 3            Alicia Coutts      Australia
# 4           Missy Franklin  United States
# ...                    ...            ...
# 6965      Olena Sadovnycha        Ukraine
# 6966      Kateryna Serdiuk        Ukraine
# 6967      Wietse van Alten    Netherlands
# 6968  Sandra Wagner-Sachse        Germany
# 6969             Rod White  United States
#
# [6970 rows x 2 columns]

# %%
paises = data_country.head(10).copy()

# %%
paises
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States
# 5       Ryan Lochte  United States
# 6   Allison Schmitt  United States
# 7        Ian Thorpe      Australia
# 8       Dara Torres  United States
# 9     Cindy Klassen         Canada

# %%
medallas = medallas_cp.copy()

# %%
medallas.iloc[2,0] = 'Daniel Busso'

# %%
medallas
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2      Daniel Busso  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
# 5     Alicia Coutts  24.0  2012            08/12/2012            1
# 6    Missy Franklin  17.0  2012            08/12/2012            4
# 7       Ryan Lochte  27.0  2012            08/12/2012            2
# 8   Allison Schmitt  22.0  2012            08/12/2012            3
# 9  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# ...

# %%
paises.iloc[8,0]='Daniel Busso'

# %%
paises
# Out:
#             Athlete        Country
# 0    Michael Phelps  United States
# 1  Natalie Coughlin  United States
# 2     Aleksey Nemov         Russia
# 3     Alicia Coutts      Australia
# 4    Missy Franklin  United States
# 5       Ryan Lochte  United States
# 6   Allison Schmitt  United States
# 7        Ian Thorpe      Australia
# 8      Daniel Busso  United States
# 9      Daniel Busso         Canada

# %%
data_inner = pd.merge(left = medallas, right = paises,
                      how='inner', left_on="Athlete", right_on = "Athlete")

# %%
data_inner
# Out:
#              Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008            08/24/2008            8
# 1     Michael Phelps  19.0  2004            08/29/2004            6
# 2       Daniel Busso  27.0  2012            08/12/2012            4
# 3       Daniel Busso  27.0  2012            08/12/2012            4
# 4   Natalie Coughlin  25.0  2008            08/24/2008            1
# 5   Natalie Coughlin  21.0  2004            08/29/2004            2
# 6      Aleksey Nemov  24.0  2000            10/01/2000            2
# 7      Alicia Coutts  24.0  2012            08/12/2012            1
# 8     Missy Franklin  17.0  2012            08/12/2012            4
# 9        Ryan Lochte  27.0  2012            08/12/2012            2
# 10   Allison Schmitt  22.0  2012            08/12/2012            3
#
#     Silver Medals  Bronze Medals  Total Medals        Country
# 0               0              0             8  United States
# ...

# %%
data_inner = pd.merge(left = medallas, right = paises,
                      how='right', left_on="Athlete", right_on = "Athlete")

# %%
data_inner
# Out:
#              Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1     Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2   Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 3   Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 4      Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
# 5      Alicia Coutts  24.0  2012.0            08/12/2012          1.0
# 6     Missy Franklin  17.0  2012.0            08/12/2012          4.0
# 7        Ryan Lochte  27.0  2012.0            08/12/2012          2.0
# 8    Allison Schmitt  22.0  2012.0            08/12/2012          3.0
# 9         Ian Thorpe   NaN     NaN                   NaN          NaN
# 10      Daniel Busso  27.0  2012.0            08/12/2012          4.0
# 11      Daniel Busso  27.0  2012.0            08/12/2012          4.0
#
# ...

# %%
data_inner = pd.merge(left = medallas, right = paises,
                      how='outer', left_on="Athlete", right_on = "Athlete")

# %%
data_inner
# Out:
#              Athlete   Age    Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008.0            08/24/2008          8.0
# 1     Michael Phelps  19.0  2004.0            08/29/2004          6.0
# 2       Daniel Busso  27.0  2012.0            08/12/2012          4.0
# 3       Daniel Busso  27.0  2012.0            08/12/2012          4.0
# 4   Natalie Coughlin  25.0  2008.0            08/24/2008          1.0
# 5   Natalie Coughlin  21.0  2004.0            08/29/2004          2.0
# 6      Aleksey Nemov  24.0  2000.0            10/01/2000          2.0
# 7      Alicia Coutts  24.0  2012.0            08/12/2012          1.0
# 8     Missy Franklin  17.0  2012.0            08/12/2012          4.0
# 9        Ryan Lochte  27.0  2012.0            08/12/2012          2.0
# 10   Allison Schmitt  22.0  2012.0            08/12/2012          3.0
# 11        Ian Thorpe   NaN     NaN                   NaN          NaN
#
# ...

# %%
medallas
# Out:
#             Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0    Michael Phelps  23.0  2008            08/24/2008            8
# 1    Michael Phelps  19.0  2004            08/29/2004            6
# 2      Daniel Busso  27.0  2012            08/12/2012            4
# 3  Natalie Coughlin  25.0  2008            08/24/2008            1
# 4     Aleksey Nemov  24.0  2000            10/01/2000            2
# 5     Alicia Coutts  24.0  2012            08/12/2012            1
# 6    Missy Franklin  17.0  2012            08/12/2012            4
# 7       Ryan Lochte  27.0  2012            08/12/2012            2
# 8   Allison Schmitt  22.0  2012            08/12/2012            3
# 9  Natalie Coughlin  21.0  2004            08/29/2004            2
#
#    Silver Medals  Bronze Medals  Total Medals
# 0              0              0             8
# 1              0              2             8
# 2              2              0             6
# ...

# %%
colu = medallas.columns.values.tolist()

# %%
colu
# Out:
# ['Athlete',
#  'Age',
#  'Year',
#  'Closing Ceremony Date',
#  'Gold Medals',
#  'Silver Medals',
#  'Bronze Medals',
#  'Total Medals']

# %%
df1 = pd.DataFrame(
{   'Athlete':'pepe',
 'Age':45,
 'Year':'2008',
 'Closing Ceremony Date':'08/12/2012',
 'Gold Medals':5,
 'Silver Medals':0,
 'Bronze Medals':0,
 'Total Medals':5}, index=[10],
)

# %%
df1
# Out:
#    Athlete  Age  Year Closing Ceremony Date  Gold Medals  Silver Medals  \
# 10    pepe   45  2008            08/12/2012            5              0
#
#     Bronze Medals  Total Medals
# 10              0             5

# %%
medallas2 = pd.concat([medallas, df1])

# %%
medallas2
# Out:
#              Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008            08/24/2008            8
# 1     Michael Phelps  19.0  2004            08/29/2004            6
# 2       Daniel Busso  27.0  2012            08/12/2012            4
# 3   Natalie Coughlin  25.0  2008            08/24/2008            1
# 4      Aleksey Nemov  24.0  2000            10/01/2000            2
# 5      Alicia Coutts  24.0  2012            08/12/2012            1
# 6     Missy Franklin  17.0  2012            08/12/2012            4
# 7        Ryan Lochte  27.0  2012            08/12/2012            2
# 8    Allison Schmitt  22.0  2012            08/12/2012            3
# 9   Natalie Coughlin  21.0  2004            08/29/2004            2
# 10              pepe  45.0  2008            08/12/2012            5
#
#     Silver Medals  Bronze Medals  Total Medals
# 0               0              0             8
# 1               0              2             8
# ...

# %%
data_join = pd.merge(left = medallas2, right = paises,
                      how='inner', left_on="Athlete", right_on = "Athlete")

# %%
data_join
# Out:
#              Athlete   Age  Year Closing Ceremony Date  Gold Medals  \
# 0     Michael Phelps  23.0  2008            08/24/2008            8
# 1     Michael Phelps  19.0  2004            08/29/2004            6
# 2       Daniel Busso  27.0  2012            08/12/2012            4
# 3       Daniel Busso  27.0  2012            08/12/2012            4
# 4   Natalie Coughlin  25.0  2008            08/24/2008            1
# 5   Natalie Coughlin  21.0  2004            08/29/2004            2
# 6      Aleksey Nemov  24.0  2000            10/01/2000            2
# 7      Alicia Coutts  24.0  2012            08/12/2012            1
# 8     Missy Franklin  17.0  2012            08/12/2012            4
# 9        Ryan Lochte  27.0  2012            08/12/2012            2
# 10   Allison Schmitt  22.0  2012            08/12/2012            3
#
#     Silver Medals  Bronze Medals  Total Medals        Country
# 0               0              0             8  United States
# ...
