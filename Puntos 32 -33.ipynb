# %%
import numpy as np
import pandas as pd

# %%
tabla = pd.read_csv('datasets/titanic/titanic3.csv')

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tabla.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
pd.isnull(tabla["body"])
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
#         ...
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# Name: body, Length: 1309, dtype: bool

# %%
tabla.dropna(axis=0, how="all")
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tabla.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
tabla.shape
# Out:
# (1309, 14)

# %%
tr = tabla.dropna(axis=0, how="any")

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tr = tabla.dropna(thresh=3)

# %%
tr
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tr
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c5d84736ba45> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-a975c295ddea> in <module>
# ----> 1 date
#
# NameError: name 'date' is not defined

# %%
date()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-801a44dc1668> in <module>
# ----> 1 date()
#
# NameError: name 'date' is not defined

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tabla[1304:][:]
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
tabla[1304:]['age']
# Out:
# 1304    14.5
# 1305     NaN
# 1306    26.5
# 1307    27.0
# 1308    29.0
# Name: age, dtype: float64

# %%
tabla[1304:].values
# Out:
# array([[3, 0, 'Zabour, Miss. Hileni', 'female', 14.5, 1, 0, '2665',
#         14.4542, nan, 'C', nan, 328.0, nan],
#        [3, 0, 'Zabour, Miss. Thamine', 'female', nan, 1, 0, '2665',
#         14.4542, nan, 'C', nan, nan, nan],
#        [3, 0, 'Zakarian, Mr. Mapriededer', 'male', 26.5, 0, 0, '2656',
#         7.225, nan, 'C', nan, 304.0, nan],
#        [3, 0, 'Zakarian, Mr. Ortin', 'male', 27.0, 0, 0, '2670', 7.225,
#         nan, 'C', nan, nan, nan],
#        [3, 0, 'Zimmerman, Mr. Leo', 'male', 29.0, 0, 0, '315082', 7.875,
#         nan, 'S', nan, nan, nan]], dtype=object)

# %%
tabla[0:11]['age']
# Out:
# 0     29.0000
# 1      0.9167
# 2      2.0000
# 3     30.0000
# 4     25.0000
# 5     48.0000
# 6     63.0000
# 7     39.0000
# 8     53.0000
# 9     71.0000
# 10    47.0000
# Name: age, dtype: float64

# %%
tabla[12:21]['name']
# Out:
# 12                      Aubart, Mme. Leontine Pauline
# 13                       Barber, Miss. Ellen "Nellie"
# 14               Barkworth, Mr. Algernon Henry Wilson
# 15                                Baumann, Mr. John D
# 16                           Baxter, Mr. Quigg Edmond
# 17    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18                              Bazzani, Miss. Albina
# 19                               Beattie, Mr. Thomson
# 20                      Beckwith, Mr. Richard Leonard
# Name: name, dtype: object

# %%
tabla.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
tabla['age'].describe()
# Out:
# count    1046.000000
# mean       29.881135
# std        14.413500
# min         0.166700
# 25%        21.000000
# 50%        28.000000
# 75%        39.000000
# max        80.000000
# Name: age, dtype: float64

# %%
tabla[0:1000]['age'].describe()
# Out:
# count    861.000000
# mean      31.084204
# std       14.398285
# min        0.166700
# 25%       22.000000
# 50%       29.000000
# 75%       40.000000
# max       80.000000
# Name: age, dtype: float64

# %%
tabla[0:20][['name', 'age']]
# Out:
#                                                  name      age
# 0                       Allen, Miss. Elisabeth Walton  29.0000
# 1                      Allison, Master. Hudson Trevor   0.9167
# 2                        Allison, Miss. Helen Loraine   2.0000
# 3                Allison, Mr. Hudson Joshua Creighton  30.0000
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  25.0000
# 5                                 Anderson, Mr. Harry  48.0000
# 6                   Andrews, Miss. Kornelia Theodosia  63.0000
# 7                              Andrews, Mr. Thomas Jr  39.0000
# 8       Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0000
# 9                             Artagaveytia, Mr. Ramon  71.0000
# 10                             Astor, Col. John Jacob  47.0000
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0000
# 12                      Aubart, Mme. Leontine Pauline  24.0000
# 13                       Barber, Miss. Ellen "Nellie"  26.0000
# ...

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tabla[10:30]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
# 16       1         0                           Baxter, Mr. Quigg Edmond
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
# 19       1         0                               Beattie, Mr. Thomson
# 20       1         1                      Beckwith, Mr. Richard Leonard
# 21       1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# ...

# %%
tabla[10:30][['survived', 'name', 'sex', 'age']]
# Out:
#     survived                                               name     sex   age
# 10         0                             Astor, Col. John Jacob    male  47.0
# 11         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12         1                      Aubart, Mme. Leontine Pauline  female  24.0
# 13         1                       Barber, Miss. Ellen "Nellie"  female  26.0
# 14         1               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 15         0                                Baumann, Mr. John D    male   NaN
# 16         0                           Baxter, Mr. Quigg Edmond    male  24.0
# 17         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18         1                              Bazzani, Miss. Albina  female  32.0
# 19         0                               Beattie, Mr. Thomson    male  36.0
# 20         1                      Beckwith, Mr. Richard Leonard    male  37.0
# ...

# %%
tabla
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
tabla['age'] > 35
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
tabla[tabla['age'] > 35]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %%
titanic = tabla

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic["pclass"]
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64

# %%
titanic['pclass'].isin([2,3])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: pclass, Length: 1309, dtype: bool

# %%
titanic[titanic['pclass'].isin([2,3])]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male  30.0
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0
# 325        2         0         Aldworth, Mr. Charles Augustus    male  30.0
# 326        2         0             Andrew, Mr. Edgardo Samuel    male  18.0
# 327        2         0               Andrew, Mr. Frank Thomas    male  25.0
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female   NaN
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male  27.0
# 1308       3         0                     Zimmerman, Mr. Leo    male  29.0
#
# ...

# %%
titanic[titanic['pclass'].isin([1])]
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 318       1         0           Williams-Lambert, Mr. Fletcher Fellows
# 319       1         1                        Wilson, Miss. Helen Alice
# 320       1         1                                Woolner, Mr. Hugh
# 321       1         0                               Wright, Mr. George
# 322       1         1                         Young, Miss. Marie Grice
#
#         sex      age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
titanic[titanic['age'].notna()]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1301       3         0                             Youseff, Mr. Gerious
# 1304       3         0                             Zabour, Miss. Hileni
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic[titanic['age'].isna()]
# Out:
#       pclass  survived                                               name  \
# 15         1         0                                Baumann, Mr. John D
# 37         1         1      Bradley, Mr. George ("George Arthur Brayton")
# 40         1         0                          Brewe, Dr. Arthur Jackson
# 46         1         0                              Cairns, Mr. Alexander
# 59         1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex  age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
1046 + 263
# Out:
# 1309

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['age']>35
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Name: age, Length: 1309, dtype: bool

# %%
titanic[titanic['age']>35]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %%
titanic.loc[titanic['age']>35, :]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %%
titanic.loc[titanic['age']>35, 'pclass':'age']
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age
# 5       male  48.0
# 6     female  63.0
# 7       male  39.0
# 8     female  53.0
# ...

# %%
titanic.iloc[9:25, 2:5]
# Out:
#                                                  name     sex   age
# 9                             Artagaveytia, Mr. Ramon    male  71.0
# 10                             Astor, Col. John Jacob    male  47.0
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.0
# 12                      Aubart, Mme. Leontine Pauline  female  24.0
# 13                       Barber, Miss. Ellen "Nellie"  female  26.0
# 14               Barkworth, Mr. Algernon Henry Wilson    male  80.0
# 15                                Baumann, Mr. John D    male   NaN
# 16                           Baxter, Mr. Quigg Edmond    male  24.0
# 17    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0
# 18                              Bazzani, Miss. Albina  female  32.0
# 19                               Beattie, Mr. Thomson    male  36.0
# 20                      Beckwith, Mr. Richard Leonard    male  37.0
# 21   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0
# ...

# %%
titanic.iloc[1:25, :]
# Out:
#     pclass  survived                                              name  \
# 1        1         1                    Allison, Master. Hudson Trevor
# 2        1         0                      Allison, Miss. Helen Loraine
# 3        1         0              Allison, Mr. Hudson Joshua Creighton
# 4        1         0   Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5        1         1                               Anderson, Mr. Harry
# 6        1         1                 Andrews, Miss. Kornelia Theodosia
# 7        1         0                            Andrews, Mr. Thomas Jr
# 8        1         1     Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9        1         0                                              PEPE
# 10       1         0                                              PEPE
# 11       1         1                                              PEPE
# 12       1         1                                              PEPE
# ...

# %%
d = {"b": 1, "a": 0, "c": 2}
d
# Out:
# {'b': 1, 'a': 0, 'c': 2}

# %%
d = {"b": 1, "a": 0, "c": 2, 'a':100}
d
# Out:
# {'b': 1, 'a': 100, 'c': 2}

# %%
d
# Out:
# {'b': 1, 'a': 100, 'c': 2}

# %%
s = pd.Series(d)

# %%
s
# Out:
# b      1
# a    100
# c      2
# dtype: int64

# %%
d = {"one": [1.0, 2.0, 3.0, 4.0], "two": [4.0, 3.0, 2.0, 1.0]}

# %%
d
# Out:
# {'one': [1.0, 2.0, 3.0, 4.0], 'two': [4.0, 3.0, 2.0, 1.0]}

# %%
df = pd.DataFrame(d)
df
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
df['one']
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: one, dtype: float64

# %%
df[1:3]
# Out:
#    one  two
# 1  2.0  3.0
# 2  3.0  2.0

# %%
df['tres'] = df['one'] + df['two']

# %%
df
# Out:
#    one  two  tres
# 0  1.0  4.0   5.0
# 1  2.0  3.0   5.0
# 2  3.0  2.0   5.0
# 3  4.0  1.0   5.0

# %%
df['cuatro'] = df['two'] * df['tres']

# %%
df
# Out:
#    one  two  tres  cuatro
# 0  1.0  4.0   5.0    20.0
# 1  2.0  3.0   5.0    15.0
# 2  3.0  2.0   5.0    10.0
# 3  4.0  1.0   5.0     5.0

# %%
df['cinco'] = df['cuatro'] > 10

# %%
df
# Out:
#    one  two  tres  cuatro  cinco
# 0  1.0  4.0   5.0    20.0   True
# 1  2.0  3.0   5.0    15.0   True
# 2  3.0  2.0   5.0    10.0  False
# 3  4.0  1.0   5.0     5.0  False

# %%
del df['cinco']

# %%
df
# Out:
#    one  two  tres  cuatro
# 0  1.0  4.0   5.0    20.0
# 1  2.0  3.0   5.0    15.0
# 2  3.0  2.0   5.0    10.0
# 3  4.0  1.0   5.0     5.0

# %%
df['señal'] = df['cuatro'] > 10

# %%
df
# Out:
#    one  two  tres  cuatro  señal
# 0  1.0  4.0   5.0    20.0   True
# 1  2.0  3.0   5.0    15.0   True
# 2  3.0  2.0   5.0    10.0  False
# 3  4.0  1.0   5.0     5.0  False

# %%
df['pi'] = 3.14151629

# %%
df
# Out:
#    one  two  tres  cuatro  señal        pi
# 0  1.0  4.0   5.0    20.0   True  3.141516
# 1  2.0  3.0   5.0    15.0   True  3.141516
# 2  3.0  2.0   5.0    10.0  False  3.141516
# 3  4.0  1.0   5.0     5.0  False  3.141516

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   one     4 non-null      float64
#  1   two     4 non-null      float64
#  2   tres    4 non-null      float64
#  3   cuatro  4 non-null      float64
#  4   señal   4 non-null      bool
#  5   pi      4 non-null      float64
# dtypes: bool(1), float64(5)
# memory usage: 292.0 bytes

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic['age'].mean()
# Out:
# 29.8811345124283

# %%
titanic['age'].median()
# Out:
# 28.0

# %%
titanic['fare'].median()
# Out:
# 14.4542
