# %%
import numpy as np

# %%
import pandas as pd

# %%
# Regresion lineal

# %%
x = 1.5 + 2.5 * np.random.randn(100)

# %%
x
# Out:
# array([ 0.65610893, -0.8898484 , -1.35846025,  1.67241132,  1.9406349 ,
#         1.81364717, -0.21552967,  1.48662049, -3.44105805,  1.50788778,
#        -2.02192312,  1.05068625,  4.90110213, -1.74247384,  4.33899997,
#         4.09813757,  2.51170115, -0.39523728,  1.16302526,  0.81576626,
#         3.79051204,  0.87603914, -0.18627944, -2.60523987,  2.76129714,
#        -0.31278382,  1.03594058, -3.0904802 ,  2.46389422, -1.04864999,
#         1.17689689, -0.45801464,  1.29333631, -1.54915933,  2.49938855,
#         4.91714969, -0.25732548,  2.55259505,  3.60686177,  0.70650143,
#         1.20396475,  1.52312563,  0.05711131,  4.16401768,  3.40081369,
#        -1.70379582, -0.97158761,  2.57679087,  3.88571302,  4.98841256,
#         2.38169519,  0.14549991,  0.93314941,  2.594893  , -2.97353306,
#        -0.17364216,  3.82889964,  2.98457874,  1.56123835,  3.6703404 ,
#         4.81627705,  0.91598887,  5.8944509 , -3.40261664,  3.03183247,
# ...

# %%
res = 0 + 0.8 * np.random.randn(100)

# %%
res
# Out:
# array([ 1.25413391,  0.24235724, -0.30234842, -0.31916037,  0.28624785,
#         0.15281702,  0.26477261,  0.70947765, -0.34278763,  0.3045015 ,
#        -0.51400676, -0.07511168,  0.55956382, -0.52033682, -0.544333  ,
#         0.88934349, -0.7837787 , -0.07184423, -0.33854214,  0.36957258,
#        -0.058094  ,  1.23153417,  1.80753535,  0.02424578,  0.47902852,
#         0.18830097,  0.27935172, -0.22392216, -0.02696514, -0.64836144,
#         1.13042155, -0.47215163, -1.08666822, -0.83073513,  0.40142501,
#        -0.62527661,  0.79943252, -0.0129995 ,  0.2132385 ,  0.09006911,
#        -0.89991228,  1.16482709, -1.31355022, -2.07286467,  0.71177484,
#         1.1143616 ,  0.39597973,  0.80008777,  1.27449606,  0.47014525,
#         0.24134699,  0.14509396, -0.64656612, -1.72220241, -0.05824141,
#        -1.15461377,  0.59930526, -0.39202195,  0.23214597,  0.12809481,
#         0.53104017, -1.18511566, -0.58093467,  0.07745538,  0.77989607,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(x)
plt.show()

# %%
plt.plot(res)
plt.show()

# %%
normales = np.random.randn(10)

# %%
normales
# Out:
# array([-1.54164676, -1.6397587 ,  0.84588492,  0.58909352, -3.46958734,
#         1.93672115,  0.13368145,  2.11874535, -0.03355266, -0.70127127])

# %%
x2 = np.random.normal(0, 1, (10))

# %%
n2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-528cf5403c0c> in <module>
# ----> 1 n2
#
# NameError: name 'n2' is not defined

# %%
x2
# Out:
# array([-0.62176342,  0.37397022, -0.32655017, -0.13319694,  0.95417735,
#        -0.77523965,  1.16275732,  0.03562027, -0.49510297,  2.66062553])

# %%
x2 = np.random.normal(0, 0.2, (10))
x2
# Out:
# array([-0.06621009, -0.02571236, -0.08692825,  0.29913957,  0.49764148,
#         0.15406433,  0.1824104 , -0.20881995,  0.02812937, -0.22356726])

# %%
# Modelo Lineal

# %% [markdown]
# # Modelo Lineal

# %% [markdown]
# # Función recta
